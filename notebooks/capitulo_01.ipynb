# %%
lista = [10, 20, 30]
len(lista)
# Out:
# 3

# %%
class Caixa:
    def __len__(self):
        return 200

# %%
c = Caixa()

# %%
len(c)
# Out:
# 200

# %%
class Livro:
    def __len__(self):
        return 300

# %%
livro = Livro()
print(len(livro))  # Saída: 300
# Out:
# 300
